# %% [markdown]
# ### 20% of customers (Cluster 0) generate over 60% of revenue.
#
# Cluster 2 customers need re-engagement to prevent further loss.
#
# Cluster 3 shows promise — they’re on track to become loyalists with the right strategy.
#
# Targeted actions can improve overall Customer Lifetime Value (CLV) and reduce churn

# %% [markdown]
# | Business Goal           :   | Action                              :         | Expected Outcome
#
#
#  **Boost Retention** :        Launch loyalty rewards for Cluster 0 & 3     Launch loyalty rewards for Cluster 0 & 3
#  **Increase Conversion**     Use personalized marketing for Cluster 1      Convert occasional buyers
#  **Recover Lost Customers**  Reactivate Cluster 2 with win-back campaigns  Reduce churn by 10–15%
#  **Improve Revenue**         Upsell/cross-sell to Cluster 3                20–25% uplift in sales per customer

# %% [markdown]
# #### This segmentation provides a data-driven understanding of the customer base, enabling targeted and personalized strategies.
# #### By focusing marketing efforts on high-value and potential loyal segments, and re-engaging at-risk customers, the company can enhance customer satisfaction, retention, and overall profitability.
